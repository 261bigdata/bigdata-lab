# %% [markdown]
# # Consumer Kafka con Spark Structured Streaming
#
# Cuaderno base para consumir el topic `orden-eventos` desde Spark y parsear el JSON
# con un esquema común que funcione tanto si el productor fue hecho en **Java** como en **Python**.
#
# ## Objetivo
# 1. Conectarse a Kafka
# 2. Leer mensajes del topic `orden-eventos`
# 3. Convertir `value` a texto
# 4. Parsear el JSON
# 5. Filtrar eventos válidos
# 6. Mostrar en consola los eventos con `total > 100`
#
# ## Datos del entorno
# - Kafka broker interno: `ec-kafka:9092`
# - Topic: `orden-eventos`
# - Spark: paquete Kafka para Spark SQL

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkOrdenes") \
    .config(
        "spark.jars.packages",
        "org.apache.spark:spark-sql-kafka-0-10_2.13:4.1.1"
    ) \
    .getOrCreate()

#spark.sparkContext.setLogLevel("WARN")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/usr/local/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-654e692e-6cb2-4dbd-89ed-d7b569aa0bf7;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.1 in central
# 	found org.apache.kafka#kafka-clients;3.9.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.8 in central
# 	found org.slf4j#slf4j-api;2.0.17 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.4.2 in central
# 	found org.apache.hadoop#hadoop-client-api;3.4.2 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found org.apache.commons#commons-pool2;2.12.1 in central
# :: resolution report :: resolve 1077ms :: artifacts dl 45ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	org.apache.commons#commons-pool2;2.12.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.4.2 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.4.2 from central in [default]
# 	org.apache.kafka#kafka-clients;3.9.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.17 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-654e692e-6cb2-4dbd-89ed-d7b569aa0bf7
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/29ms)
# 26/04/17 20:58:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
print("Spark:", spark.version)
print("Scala JVM:", spark.sparkContext._jvm.scala.util.Properties.versionNumberString())
# Out:
# Spark: 4.1.1
# Scala JVM: 2.13.17

# %% [markdown]
# ## Paso 1. Leer el stream desde Kafka
#
# Aquí todavía no parseamos el JSON. Solo leemos los mensajes crudos del topic.

# %%
df_kafka = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "ec-kafka:9092") \
    .option("subscribe", "orden-eventos") \
    .option("startingOffsets", "earliest") \
    .load()

# %%
df_kafka.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %% [markdown]
# ## Paso 2. Convertir `value` a texto (Saltar al paso 3)
#
# Kafka entrega `key` y `value` en binario. Por eso primero convertimos `value` a `STRING`.

# %%
df_texto = df_kafka.selectExpr("CAST(value AS STRING) AS mensaje")
df_texto.printSchema()
# Out:
# root
#  |-- mensaje: string (nullable = true)

# %%
# Vista rápida del mensaje en texto
# Si quieres depurar primero sin parsear JSON, ejecuta esta celda.
query_texto = df_texto.writeStream \
    .format("console") \
    .outputMode("append") \
    .option("truncate", False) \
    .start()
# Out:
# 26/04/16 01:34:51 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-b6bab6fb-46e4-4fee-ad3c-b4584789526a. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/16 01:34:51 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------------------------------------------------------------------------+
# |mensaje                                                                    |
# +---------------------------------------------------------------------------+
# |hi                                                                         |
# |orden 1                                                                    |
# |{"tipoEvento":"orden.creada","ordenId":1,"estado":"PENDIENTE"}             |
# |{"tipoEvento":"orden.creada","ordenId":2,"estado":"PENDIENTE"}             |
# |{"tipoEvento":"orden.creada","ordenId":3,"estado":"PENDIENTE"}             |
# |{"tipoEvento":"orden.creada","ordenId":4,"estado":"PENDIENTE"}             |
# |{"tipoEvento":"orden.creada","ordenId":5,"estado":"PENDIENTE"}             |
# |{"tipoEvento":"orden.creada","ordenId":6,"estado":"PENDIENTE"}             |
# |orden a                                                                    |
# |{"tipoEvento":"orden.creada","ordenId":7,"total":90.0,"estado":"PENDIENTE"}|
# +---------------------------------------------------------------------------+

# %% [markdown]
# Cuando termines de ver mensajes crudos, detén la consulta antes de seguir:

# %%
query_texto.stop()
# Out:
# 26/04/16 01:35:07 WARN DAGScheduler: Failed to cancel job group d1d054d2-6614-4048-8431-f678a903fd5e. Cannot find active jobs for it.
# 26/04/16 01:35:07 WARN DAGScheduler: Failed to cancel job group d1d054d2-6614-4048-8431-f678a903fd5e. Cannot find active jobs for it.

# %% [markdown]
# ## Paso 3. Definir el esquema común del evento
#
# Este contrato permite que Spark interprete igual los mensajes vengan de Java o de Python.
#
# ### Evento esperado
# ```json
# {
#   "tipoEvento": "orden.creada",
#   "ordenId": 1,
#   "total": 150.0,
#   "estado": "PENDIENTE",
#   "origen": "java",
#   "timestamp": 1710000000
# }
# ```
#
# Los campos `origen` y `timestamp` son opcionales.

# %%
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import StructType, StructField, StringType, LongType, DoubleType

schema = StructType([
    StructField("tipoEvento", StringType(), True),
    StructField("ordenId", LongType(), True),
    StructField("total", DoubleType(), True),
    StructField("estado", StringType(), True),
    StructField("origen", StringType(), True),
    StructField("timestamp", LongType(), True)
])

# %% [markdown]
# ## Paso 4. Parsear el JSON

# %%
df_value = df_kafka.selectExpr("CAST(value AS STRING) AS value")

df_parsed = df_value.select(
    from_json(col("value"), schema).alias("data")
).select("data.*")

# %%
df_parsed.printSchema()
# Out:
# root
#  |-- tipoEvento: string (nullable = true)
#  |-- ordenId: long (nullable = true)
#  |-- total: double (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- origen: string (nullable = true)
#  |-- timestamp: long (nullable = true)

# %% [markdown]
# ## Paso 5. Validar registros
#
# Filtramos mensajes que sí tengan al menos el contrato básico:
# - `tipoEvento`
# - `ordenId`
# - `total`
# - `estado`

# %%
df_validado = df_parsed.filter(
    col("tipoEvento").isNotNull() &
    col("ordenId").isNotNull() &
    col("total").isNotNull() &
    col("estado").isNotNull()
)

# %% [markdown]
# ## Paso 6. Transformación de ejemplo
#
# En este caso, solo dejamos órdenes con `total > 100`.

# %%
df_transformed = df_validado.filter(col("total") > 0)

# %% [markdown]
# ## Paso 7. Salida a consola

# %%
# Momento 1: Consola debug visual
query_console = df_transformed.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()

#query_console.awaitTermination()
# Out:
# 26/04/17 21:29:52 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-c9f138fe-6345-4bb3-84eb-3791d42eb53a. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/17 21:29:52 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------------+-------+-----+---------+------+----------+
# |tipoEvento  |ordenId|total|estado   |origen|timestamp |
# +------------+-------+-----+---------+------+----------+
# |orden.creada|628    |397.0|PENDIENTE|python|1776435663|
# |orden.creada|162    |450.0|PENDIENTE|python|1776435665|
# |orden.creada|135    |74.0 |PENDIENTE|python|1776435667|
# |orden.creada|697    |177.0|PENDIENTE|python|1776435669|
# |orden.creada|18     |269.0|PENDIENTE|python|1776435671|
# |orden.creada|487    |74.0 |PENDIENTE|python|1776435673|
# |orden.creada|99     |350.0|PENDIENTE|python|1776435675|
# |orden.creada|155    |492.0|PENDIENTE|python|1776435677|
# |orden.creada|569    |51.0 |PENDIENTE|python|1776435679|
# |orden.creada|934    |255.0|PENDIENTE|python|1776435681|
# |orden.creada|102    |334.0|PENDIENTE|python|1776435904|
# |orden.creada|909    |175.0|PENDIENTE|python|1776435906|
# |orden.creada|360    |173.0|PENDIENTE|python|1776435908|
# |orden.creada|700    |179.0|PENDIENTE|python|1776435910|
# |orden.creada|349    |491.0|PENDIENTE|python|1776435912|
# |orden.creada|945    |104.0|PENDIENTE|python|1776435914|
# |orden.creada|322    |107.0|PENDIENTE|python|1776435916|
# |orden.creada|598    |356.0|PENDIENTE|python|1776435918|
# |orden.creada|936    |500.0|PENDIENTE|python|1776435920|
# |orden.creada|458    |233.0|PENDIENTE|python|1776435922|
# +------------+-------+-----+---------+------+----------+
# only showing top 20 rows

# %% [markdown]
# ## Detener la consulta
# Si necesitas detener manualmente la ejecución, puedes usar:

# %%
#query_console.stop()
# Out:
# 26/04/16 01:42:26 WARN DAGScheduler: Failed to cancel job group 37b14aa9-5ef0-4f51-989e-9f99a5e6e58f. Cannot find active jobs for it.
# 26/04/16 01:42:26 WARN DAGScheduler: Failed to cancel job group 37b14aa9-5ef0-4f51-989e-9f99a5e6e58f. Cannot find active jobs for it.

# %% [markdown]
# ## Ejemplos de productores compatibles
#
# ### Java
# ```java
# @NoArgsConstructor
# @AllArgsConstructor
# public class EventoOrden {
#     private String tipoEvento;
#     private Long ordenId;
#     private Double total;
#     private String estado;
# }
# ```
#
# ### Python
# ```python
# from kafka import KafkaProducer
# import json, time, random
#
# producer = KafkaProducer(
#     bootstrap_servers='ec-kafka:9092',
#     value_serializer=lambda v: json.dumps(v).encode('utf-8')
# )
#
# while True:
#     data = {
#         "tipoEvento": "orden.creada",
#         "ordenId": random.randint(1, 1000),
#         "total": random.randint(50, 1500),
#         "estado": "PENDIENTE",
#         "origen": "python",
#         "timestamp": int(time.time())
#     }
#
#     producer.send("orden-eventos", value=data)
#     print("Enviado:", data)
#     time.sleep(2)
# ```

# %%
# Momento 2: persistencia Arrancar stream a Parquet o Salida a Parquet

query_parquet = df_transformed.writeStream \
    .format("parquet") \
    .option("path", "/opt/artifacts/output/orden_eventos_parquet") \
    .option("checkpointLocation", "/opt/artifacts/checkpoint/orden-eventos") \
    .outputMode("append") \
    .start()
# Out:
# 26/04/17 21:33:44 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.

# %%
#Esperar micro-batch
import time
time.sleep(10)

# %%
#Leer lo guardado
df_final = spark.read.parquet("/opt/artifacts/output/orden_eventos_parquet")

df_final.show(200, truncate=False)
# Out:
# +------------+-------+-------+---------+-----------+----------+
# |tipoEvento  |ordenId|total  |estado   |origen     |timestamp |
# +------------+-------+-------+---------+-----------+----------+
# |orden.creada|628    |397.0  |PENDIENTE|python     |1776435663|
# |orden.creada|162    |450.0  |PENDIENTE|python     |1776435665|
# |orden.creada|135    |74.0   |PENDIENTE|python     |1776435667|
# |orden.creada|697    |177.0  |PENDIENTE|python     |1776435669|
# |orden.creada|18     |269.0  |PENDIENTE|python     |1776435671|
# |orden.creada|487    |74.0   |PENDIENTE|python     |1776435673|
# |orden.creada|99     |350.0  |PENDIENTE|python     |1776435675|
# |orden.creada|155    |492.0  |PENDIENTE|python     |1776435677|
# |orden.creada|569    |51.0   |PENDIENTE|python     |1776435679|
# |orden.creada|934    |255.0  |PENDIENTE|python     |1776435681|
# |orden.creada|102    |334.0  |PENDIENTE|python     |1776435904|
# |orden.creada|909    |175.0  |PENDIENTE|python     |1776435906|
# |orden.creada|360    |173.0  |PENDIENTE|python     |1776435908|
# |orden.creada|700    |179.0  |PENDIENTE|python     |1776435910|
# |orden.creada|349    |491.0  |PENDIENTE|python     |1776435912|
# |orden.creada|945    |104.0  |PENDIENTE|python     |1776435914|
# |orden.creada|322    |107.0  |PENDIENTE|python     |1776435916|
# |orden.creada|598    |356.0  |PENDIENTE|python     |1776435918|
# |orden.creada|936    |500.0  |PENDIENTE|python     |1776435920|
# |orden.creada|458    |233.0  |PENDIENTE|python     |1776435922|
# |orden.creada|927    |485.0  |PENDIENTE|python     |1776435924|
# |orden.creada|165    |252.0  |PENDIENTE|python     |1776435926|
# |orden.creada|550    |203.0  |PENDIENTE|python     |1776436024|
# |orden.creada|928    |287.0  |PENDIENTE|python     |1776436026|
# |orden.creada|641    |184.0  |PENDIENTE|python     |1776436028|
# |orden.creada|279    |181.0  |PENDIENTE|python     |1776436030|
# |orden.creada|82     |358.0  |PENDIENTE|python     |1776436032|
# |orden.creada|512    |266.0  |PENDIENTE|python     |1776436034|
# |orden.creada|112    |473.0  |PENDIENTE|python     |1776436036|
# |orden.creada|504    |407.0  |PENDIENTE|python     |1776436038|
# |orden.creada|508    |211.0  |PENDIENTE|python     |1776436040|
# |orden.creada|19     |384.0  |PENDIENTE|python     |1776436042|
# |orden.creada|208    |74.0   |PENDIENTE|python     |1776436044|
# |orden.creada|590    |301.0  |PENDIENTE|python     |1776436046|
# |orden.creada|5      |173.0  |PENDIENTE|python     |1776436048|
# |orden.creada|257    |249.0  |PENDIENTE|python     |1776436050|
# |orden.creada|819    |187.0  |PENDIENTE|python     |1776436052|
# |orden.creada|695    |473.0  |PENDIENTE|python     |1776436054|
# |orden.creada|912    |58.0   |PENDIENTE|python     |1776436056|
# |orden.creada|789    |169.0  |PENDIENTE|python     |1776436058|
# |orden.creada|638    |210.0  |PENDIENTE|python     |1776436060|
# |orden.creada|366    |304.0  |PENDIENTE|python     |1776436062|
# |orden.creada|81     |123.0  |PENDIENTE|python     |1776436062|
# |orden.creada|481    |150.0  |PENDIENTE|python     |1776436064|
# |orden.creada|610    |294.0  |PENDIENTE|python     |1776436064|
# |orden.creada|266    |463.0  |PENDIENTE|python     |1776436066|
# |orden.creada|272    |65.0   |PENDIENTE|python     |1776436066|
# |orden.creada|151    |337.0  |PENDIENTE|python     |1776436068|
# |orden.creada|130    |265.0  |PENDIENTE|python     |1776436068|
# |orden.creada|106    |219.0  |PENDIENTE|python     |1776436070|
# |orden.creada|493    |141.0  |PENDIENTE|python     |1776436070|
# |orden.creada|804    |425.0  |PENDIENTE|python     |1776436072|
# |orden.creada|532    |445.0  |PENDIENTE|python     |1776436072|
# |orden.creada|828    |203.0  |PENDIENTE|python     |1776436074|
# |orden.creada|418    |360.0  |PENDIENTE|python     |1776436074|
# |orden.creada|929    |387.0  |PENDIENTE|python     |1776436076|
# |orden.creada|923    |121.0  |PENDIENTE|python     |1776436076|
# |orden.creada|551    |117.0  |PENDIENTE|python     |1776436078|
# |orden.creada|121    |442.0  |PENDIENTE|python     |1776436078|
# |orden.creada|729    |324.0  |PENDIENTE|python     |1776436080|
# |orden.creada|242    |79.0   |PENDIENTE|python     |1776436080|
# |orden.creada|821    |473.0  |PENDIENTE|python     |1776436082|
# |orden.creada|70     |418.0  |PENDIENTE|python     |1776436082|
# |orden.creada|692    |462.0  |PENDIENTE|python     |1776436084|
# |orden.creada|164    |474.0  |PENDIENTE|python     |1776436084|
# |orden.creada|869    |172.0  |PENDIENTE|python     |1776436086|
# |orden.creada|141    |487.0  |PENDIENTE|python     |1776436086|
# |orden.creada|25     |190.0  |PENDIENTE|python     |1776436088|
# |orden.creada|998    |59.0   |PENDIENTE|python     |1776436088|
# |orden.creada|529    |69.0   |PENDIENTE|python     |1776436090|
# |orden.creada|309    |247.0  |PENDIENTE|python     |1776436090|
# |orden.creada|74     |348.0  |PENDIENTE|python     |1776436092|
# |orden.creada|746    |351.0  |PENDIENTE|python     |1776436092|
# |orden.creada|600    |338.0  |PENDIENTE|python     |1776436094|
# |orden.creada|710    |391.0  |PENDIENTE|python     |1776436094|
# |orden.creada|215    |136.0  |PENDIENTE|python     |1776436096|
# |orden.creada|78     |111.0  |PENDIENTE|python     |1776436096|
# |orden.creada|38     |115.0  |PENDIENTE|python     |1776436098|
# |orden.creada|810    |224.0  |PENDIENTE|python     |1776436098|
# |orden.creada|577    |416.0  |PENDIENTE|python     |1776436100|
# |orden.creada|306    |223.0  |PENDIENTE|python     |1776436100|
# |orden.creada|978    |211.0  |PENDIENTE|python     |1776436102|
# |orden.creada|154    |52.0   |PENDIENTE|python     |1776436102|
# |orden.creada|139    |470.0  |PENDIENTE|python     |1776436104|
# |orden.creada|658    |66.0   |PENDIENTE|python     |1776436104|
# |orden.creada|580    |131.0  |PENDIENTE|python     |1776436106|
# |orden.creada|33     |67.0   |PENDIENTE|python     |1776436106|
# |orden.creada|843    |484.0  |PENDIENTE|python     |1776436108|
# |orden.creada|630    |347.0  |PENDIENTE|python     |1776436108|
# |orden.creada|414    |462.0  |PENDIENTE|python     |1776436110|
# |orden.creada|926    |86.0   |PENDIENTE|python     |1776436110|
# |orden.creada|701    |401.0  |PENDIENTE|python     |1776436112|
# |orden.creada|363    |205.0  |PENDIENTE|python     |1776436112|
# |orden.creada|672    |361.0  |PENDIENTE|python     |1776436114|
# |orden.creada|763    |479.0  |PENDIENTE|python     |1776436114|
# |orden.creada|159    |121.0  |PENDIENTE|python     |1776436116|
# |orden.creada|459    |196.0  |PENDIENTE|python     |1776436116|
# |orden.creada|460    |376.0  |PENDIENTE|python     |1776436118|
# |orden.creada|311    |253.0  |PENDIENTE|python     |1776436118|
# |orden.creada|86     |479.0  |PENDIENTE|python     |1776436120|
# |orden.creada|253    |364.0  |PENDIENTE|python     |1776436120|
# |orden.creada|230    |360.0  |PENDIENTE|python     |1776436122|
# |orden.creada|864    |94.0   |PENDIENTE|python     |1776436122|
# |orden.creada|723    |250.0  |PENDIENTE|python     |1776436124|
# |orden.creada|889    |64.0   |PENDIENTE|python     |1776436124|
# |orden.creada|788    |370.0  |PENDIENTE|python     |1776436126|
# |orden.creada|662    |141.0  |PENDIENTE|python     |1776436126|
# |orden.creada|493    |390.0  |PENDIENTE|python     |1776436128|
# |orden.creada|282    |221.0  |PENDIENTE|python     |1776436128|
# |orden.creada|867    |391.0  |PENDIENTE|python     |1776436130|
# |orden.creada|116    |220.0  |PENDIENTE|python     |1776436130|
# |orden.creada|919    |256.0  |PENDIENTE|python     |1776436132|
# |orden.creada|628    |250.0  |PENDIENTE|python     |1776436132|
# |orden.creada|283    |488.0  |PENDIENTE|python     |1776436134|
# |orden.creada|21     |459.0  |PENDIENTE|python     |1776436134|
# |orden.creada|915    |378.0  |PENDIENTE|python     |1776436136|
# |orden.creada|911    |206.0  |PENDIENTE|python     |1776436136|
# |orden.creada|36     |384.0  |PENDIENTE|python     |1776436138|
# |orden.creada|326    |401.0  |PENDIENTE|python     |1776436138|
# |orden.creada|103    |409.0  |PENDIENTE|python     |1776436140|
# |orden.creada|116    |418.0  |PENDIENTE|python     |1776436140|
# |orden.creada|47     |331.0  |PENDIENTE|python     |1776436142|
# |orden.creada|154    |237.0  |PENDIENTE|python     |1776436142|
# |orden.creada|238    |265.0  |PENDIENTE|python     |1776436144|
# |orden.creada|689    |78.0   |PENDIENTE|python     |1776436144|
# |orden.creada|466    |308.0  |PENDIENTE|python     |1776436146|
# |orden.creada|157    |172.0  |PENDIENTE|python     |1776436146|
# |orden.creada|791    |289.0  |PENDIENTE|python     |1776436148|
# |orden.creada|450    |306.0  |PENDIENTE|python     |1776436148|
# |orden.creada|443    |311.0  |PENDIENTE|python     |1776436150|
# |orden.creada|285    |235.0  |PENDIENTE|python     |1776436150|
# |orden.creada|62     |365.0  |PENDIENTE|python     |1776436152|
# |orden.creada|271    |85.0   |PENDIENTE|python     |1776436152|
# |orden.creada|190    |267.0  |PENDIENTE|python     |1776436154|
# |orden.creada|898    |390.0  |PENDIENTE|python     |1776436154|
# |orden.creada|146    |119.0  |PENDIENTE|python     |1776436156|
# |orden.creada|575    |157.0  |PENDIENTE|python     |1776436156|
# |orden.creada|866    |131.0  |PENDIENTE|python     |1776436158|
# |orden.creada|675    |380.0  |PENDIENTE|python     |1776436158|
# |orden.creada|532    |448.0  |PENDIENTE|python     |1776436160|
# |orden.creada|100    |411.0  |PENDIENTE|python     |1776454081|
# |orden.creada|72     |332.0  |PENDIENTE|python     |1776454083|
# |orden.creada|21     |0.1    |PENDIENTE|ec-orden-ms|1776455862|
# |orden.creada|22     |6660.1 |PENDIENTE|ec-orden-ms|1776460066|
# |orden.creada|23     |16660.1|PENDIENTE|ec-orden-ms|1776460852|
# |orden.creada|24     |7000.0 |PENDIENTE|ec-orden-ms|1776460969|
# |orden.creada|25     |8000.0 |PENDIENTE|ec-orden-ms|1776461659|
# +------------+-------+-------+---------+-----------+----------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +------------+-------+------+---------+-----------+----------+
# |tipoEvento  |ordenId|total |estado   |origen     |timestamp |
# +------------+-------+------+---------+-----------+----------+
# |orden.creada|26     |9999.0|PENDIENTE|ec-orden-ms|1776461792|
# +------------+-------+------+---------+-----------+----------+
#
# +------------+-------+------+---------+-----------+----------+
# |tipoEvento  |ordenId|total |estado   |origen     |timestamp |
# +------------+-------+------+---------+-----------+----------+
# |orden.creada|26     |9999.0|PENDIENTE|ec-orden-ms|1776461792|
# +------------+-------+------+---------+-----------+----------+
#
# +------------+-------+------+---------+-----------+----------+
# |tipoEvento  |ordenId|total |estado   |origen     |timestamp |
# +------------+-------+------+---------+-----------+----------+
# |orden.creada|26     |9999.0|PENDIENTE|ec-orden-ms|1776461792|
# +------------+-------+------+---------+-----------+----------+

# %%
df_final.printSchema()
# Out:
# root
#  |-- tipoEvento: string (nullable = true)
#  |-- ordenId: long (nullable = true)
#  |-- total: double (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- origen: string (nullable = true)
#  |-- timestamp: long (nullable = true)

# %%
spark.streams.active
# Out:
# [<pyspark.sql.streaming.query.StreamingQuery at 0x7fbc112a9510>,
#  <pyspark.sql.streaming.query.StreamingQuery at 0x7fbc112a9840>,
#  <pyspark.sql.streaming.query.StreamingQuery at 0x7fbc112ecbb0>,
#  <pyspark.sql.streaming.query.StreamingQuery at 0x7fbc112ef9d0>]

# %%
df_final.select("tipoEvento", "ordenId", "total", "estado").show()
# Out:
# +------------+-------+-----+---------+
# |  tipoEvento|ordenId|total|   estado|
# +------------+-------+-----+---------+
# |orden.creada|    628|397.0|PENDIENTE|
# |orden.creada|    162|450.0|PENDIENTE|
# |orden.creada|    135| 74.0|PENDIENTE|
# |orden.creada|    697|177.0|PENDIENTE|
# |orden.creada|     18|269.0|PENDIENTE|
# |orden.creada|    487| 74.0|PENDIENTE|
# |orden.creada|     99|350.0|PENDIENTE|
# |orden.creada|    155|492.0|PENDIENTE|
# |orden.creada|    569| 51.0|PENDIENTE|
# |orden.creada|    934|255.0|PENDIENTE|
# |orden.creada|    102|334.0|PENDIENTE|
# |orden.creada|    909|175.0|PENDIENTE|
# |orden.creada|    360|173.0|PENDIENTE|
# |orden.creada|    700|179.0|PENDIENTE|
# |orden.creada|    349|491.0|PENDIENTE|
# |orden.creada|    945|104.0|PENDIENTE|
# |orden.creada|    322|107.0|PENDIENTE|
# |orden.creada|    598|356.0|PENDIENTE|
# |orden.creada|    936|500.0|PENDIENTE|
# |orden.creada|    458|233.0|PENDIENTE|
# +------------+-------+-----+---------+
# only showing top 20 rows

# %%
#Detener stream cuando ya no lo necesites, Detener ambas
#query_console.stop()
#query_parquet.stop()
